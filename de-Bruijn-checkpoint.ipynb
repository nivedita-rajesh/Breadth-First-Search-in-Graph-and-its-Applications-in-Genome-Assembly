# %%
pip install toyplot
# Out:
# Requirement already satisfied: toyplot in d:\softwares\anaconda\lib\site-packages (1.0.0)
# Requirement already satisfied: arrow>=1.0 in d:\softwares\anaconda\lib\site-packages (from toyplot) (1.2.1)
# Requirement already satisfied: multipledispatch in d:\softwares\anaconda\lib\site-packages (from toyplot) (0.6.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pypng in d:\softwares\anaconda\lib\site-packages (from toyplot) (0.0.21)
# Requirement already satisfied: custom-inherit in d:\softwares\anaconda\lib\site-packages (from toyplot) (2.4.0)
# Requirement already satisfied: reportlab in d:\softwares\anaconda\lib\site-packages (from toyplot) (3.6.5)
# Requirement already satisfied: numpy>=1.8.0 in d:\softwares\anaconda\lib\site-packages (from toyplot) (1.20.3)
# Requirement already satisfied: python-dateutil>=2.7.0 in d:\softwares\anaconda\lib\site-packages (from arrow>=1.0->toyplot) (2.8.2)
# Requirement already satisfied: six>=1.5 in d:\softwares\anaconda\lib\site-packages (from python-dateutil>=2.7.0->arrow>=1.0->toyplot) (1.16.0)
# Requirement already satisfied: pillow>=4.0.0 in d:\softwares\anaconda\lib\site-packages (from reportlab->toyplot) (8.4.0)

# %%
import random
import toyplot

# %%
def get_kmer_count_from_sequence(sequence, k=3, cyclic=True):
    """
    Returns dictionary with keys representing all possible kmers in a sequence
    and values counting their occurrence in the sequence.
    """
    # dict to store kmers
    kmers = {}
    
    # count how many times each occurred in this sequence (treated as cyclic)
    for i in range(0, len(sequence)):
        kmer = sequence[i:i + k]
        
        # for cyclic sequence get kmers that wrap from end to beginning
        length = len(kmer)
        if cyclic:
            if len(kmer) != k:
                kmer += sequence[:(k - length)]
        
        # if not cyclic then skip kmers at end of sequence
        else:
            if len(kmer) != k:
                continue
        
        # count occurrence of this kmer in sequence
        if kmer in kmers:
            kmers[kmer] += 1
        else:
            kmers[kmer] = 1
    
    return kmers

# %%
def random_sequence(seqlen):
    "Generate a random DNA sequence of a given length "
    return "".join([random.choice("ACGT") for i in range(seqlen)])

# %%
random.seed(123)

# get a random genome sequence
genome1 = random_sequence(25)

# %%
kmers = get_kmer_count_from_sequence(genome1, k=3, cyclic=False)

# %%
def get_debruijn_edges_from_kmers(kmers):
    """
    Every possible (k-1)mer (n-1 suffix and prefix of kmers) is assigned
    to a node, and we connect one node to another if the (k-1)mer overlaps 
    another. Nodes are (k-1)mers, edges are kmers.
    """
    # store edges as tuples in a set
    edges = set()
    
    # compare each (k-1)mer
    for k1 in kmers:
        for k2 in kmers:
            if k1 != k2:            
                # if they overlap then add to edges
                if k1[1:] == k2[:-1]:
                    edges.add((k1[:-1], k2[:-1]))
                if k1[:-1] == k2[1:]:
                    edges.add((k2[:-1], k1[:-1]))

    return edges

# %%
edges = get_debruijn_edges_from_kmers(kmers)

# %%
